# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS * 2 **43
print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %%
# Convert meters to kilometers and display with two decimal places
print("Thickness: {: .2f} kilometers".format(folded_thickness / 10000))
# Out:
# Thickness:  70368.74 kilometers

# %%
Num_of_folds = 43
THICKNESS = 0.00008
for i in range(Num_of_folds):
    THICKNESS = THICKNESS * 2
    print(THICKNESS)
# Out:
# 0.00016
# 0.00032
# 0.00064
# 0.00128
# 0.00256
# 0.00512
# 0.01024
# 0.02048
# 0.04096
# 0.08192
# 0.16384
# 0.32768
# 0.65536
# 1.31072
# 2.62144
# 5.24288
# 10.48576
# 20.97152
# 41.94304
# 83.88608
# 167.77216
# 335.54432
# 671.08864
# 1342.17728
# 2684.35456
# 5368.70912
# 10737.41824
# 21474.83648
# 42949.67296
# 85899.34592
# 171798.69184
# 343597.38368
# 687194.76736
# 1374389.53472
# 2748779.06944
# 5497558.13888
# 10995116.27776
# 21990232.55552
# 43980465.11104
# 87960930.22208
# 175921860.44416
# 351843720.88832
# 703687441.77664

# %%
import time
start = time.time()
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 **43

print("Thickness: {} meters".format(folded_thickness))
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Thickness: 703687441.77664 meters
# time : 0.0[s]

# %%
import time
start = time.time()
Num_of_folds = 43
THICKNESS = 0.00008
for i in range(Num_of_folds):
    THICKNESS = THICKNESS * 2
    print(THICKNESS)
    elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# 0.00016
# 0.00032
# 0.00064
# 0.00128
# 0.00256
# 0.00512
# 0.01024
# 0.02048
# 0.04096
# 0.08192
# 0.16384
# 0.32768
# 0.65536
# 1.31072
# 2.62144
# 5.24288
# 10.48576
# 20.97152
# 41.94304
# 83.88608
# 167.77216
# 335.54432
# 671.08864
# 1342.17728
# 2684.35456
# 5368.70912
# 10737.41824
# 21474.83648
# 42949.67296
# 85899.34592
# 171798.69184
# 343597.38368
# 687194.76736
# 1374389.53472
# 2748779.06944
# 5497558.13888
# 10995116.27776
# 21990232.55552
# 43980465.11104
# 87960930.22208
# 175921860.44416
# 351843720.88832
# 703687441.77664
# time : 0.0[s]

# %%
folded_list = [0.00008,]
thickness = 0.00008
for i in range(43):
    thickness = thickness * 2
    folded_list.append(thickness)
    print(folded_list)
# Out:
# [8e-05, 0.00016]
# [8e-05, 0.00016, 0.00032]
# [8e-05, 0.00016, 0.00032, 0.00064]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536]
# ...

# %%
print(len(folded_list))
# Out:
# 44

# %%
import matplotlib.pyplot as plt

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_list, color='red') 
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_list, color='blue') 
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_list, color='green') 
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [20m]")
plt.plot(folded_list, color='red') 
plt.show()

# %%
git push git@github.com:midedenton/PYTHON-.git
# Out:
#   Cell In [31], line 1
#     git push git@github.com:midedenton/PYTHON-.git
#         ^
# SyntaxError: invalid syntax

# %%
git@github.com:midedenton/PYTHON-.git

# %%
git push git@github.com:[あなたのアカウント名]/for_git_study.git master
# Out:
#   Cell In [32], line 1
#     git push git@github.com:[あなたのアカウント名]/for_git_study.git master
#         ^
# SyntaxError: invalid syntax
